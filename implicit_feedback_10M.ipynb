# %%
import pandas as pd
import time
import numpy as np
from scipy import sparse
import warnings
from implicit_markov_chain import ImplicitMarkovChain
from model_helper import save_model
warnings.filterwarnings('ignore')

# Load the data
print("Loading MovieLens 20M data...")
# selected_users = pd.read_csv('data/users_selection.csv')
ratings = pd.read_csv('data/filtered_high_ratings_20251114_120514.csv')

# print(f"Movies: {movies.shape}")
print(f"Ratings: {ratings.shape}")
print("\nFirst few rows of ratings:")
print(ratings.head())
# print("\nRating distribution:")
# print(ratings['rating'].value_counts().sort_index())
# Out:
# Loading MovieLens 20M data...
# Ratings: (10246362, 4)
#
# First few rows of ratings:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %% [markdown]
# # Loop

# %%
leave_k_out = 100
n_users = 1000

all_users = ratings['userId'].unique()

iterations = 100
max_recall, max_prec = 0, 0

for iter in range(iterations):
    print(f"{iter+1}/{iterations}")
    selected_user_ids = np.random.choice(all_users, size=n_users, replace=False)

    # print(f"Selected {len(selected_user_ids)} unique users")

    filtered_ratings = ratings[ratings['userId'].isin(selected_user_ids)]
    # print(f"Original ratings shape: {ratings.shape}")
    # print(f"Filtered ratings shape: {filtered_ratings.shape}")

    filtered_ratings_sorted = filtered_ratings.sort_values(['userId', 'timestamp'])

    train_ratings = filtered_ratings_sorted.groupby('userId').apply(lambda x: x.iloc[:-leave_k_out] if len(x) > leave_k_out else pd.DataFrame()).reset_index(drop=True)
    test_ratings = filtered_ratings_sorted.groupby('userId').tail(leave_k_out)

    print(f"Training set: {train_ratings.shape[0]:,} ratings")
    print(f"Test set: {test_ratings.shape[0]:,} ratings (Leave-{leave_k_out}-out)")

    print("Training implicit feedback Markov chain...")
    model = ImplicitMarkovChain(alpha=2.0)
    start = time.time()
    model.build_transition_matrix_efficient(train_ratings, sample_fraction=1)
    print(f"{time.time() - start:.4f} seconds")

    K = 50
    total_recall = 0
    users_not_considered = 0
    recalls = []
    total_precision = 0
    user_recommendations = {}
    train_ratings_sorted = train_ratings.sort_values(['userId', 'timestamp'])

    for user_id in selected_user_ids:
        user_data = train_ratings_sorted[train_ratings_sorted['userId'] == user_id]
        user_training_samples = len(user_data)
        
        # Only consider last 5 samples
        recent_movies = user_data['movieId'].tail(1).tolist()
        
        candidate_scores = {}
        
        # Process only the last 5 movies
        for movie_id in recent_movies:
            probabilities = model.transition_matrix[model.movie_to_idx[movie_id]]
            top_indices = np.argsort(probabilities)[-(K):][::-1]
            
            for i in top_indices:
                candidate_movie_id = model.idx_to_movie[i]
                candidate_prob = probabilities[i]
                
                # Skip if user has already rated this movie
                if candidate_movie_id in user_data['movieId'].values:
                    continue
                    
                # Keep the highest probability for each movie
                if candidate_movie_id not in candidate_scores:
                    candidate_scores[candidate_movie_id] = candidate_prob
                elif candidate_prob > candidate_scores[candidate_movie_id]:
                    candidate_scores[candidate_movie_id] = candidate_prob
        
        # Get top K movies from candidate scores
        top_movies = sorted(candidate_scores.items(), key=lambda x: x[1], reverse=True)[:K]
        
        if len(top_movies) < K:
            users_not_considered += 1
            # print(f"userid: {user_id} - Insufficient recommendations: {len(top_movies)}/{K} - Skipping")
            continue
            
        candidate_movies = [movie_id for movie_id, score in top_movies]
        recommended_movies = set(candidate_movies)
        user_test_ratings = test_ratings[test_ratings['userId'] == user_id]
        relevant_movies = set(user_test_ratings['movieId'].tolist())
        
        # Validation
        hits = relevant_movies.intersection(recommended_movies)
        
        user_recall = 0
        if len(relevant_movies) > 0:
            user_recall = len(hits) / len(relevant_movies)
            total_recall += user_recall    
        recalls.append(user_recall)
        
        if len(recommended_movies) > 0:
            user_precision = len(hits) / len(recommended_movies)
            total_precision += user_precision

        # print(f"userid: {user_id} - recent_movies: {len(recent_movies)} - recommendations: {len(top_movies)} - test_data: {len(relevant_movies)} - hits: {len(hits)} - recall: {user_recall:.4f}")

    # print(f"total users: {len(selected_user_ids)} - users not consid. {users_not_considered} - total_recall: {total_recall}")

    if (len(selected_user_ids) - users_not_considered) > 0:
        avg_recall = total_recall / (len(selected_user_ids) - users_not_considered)
        avg_precision = total_precision / (len(selected_user_ids) - users_not_considered)
    else:
        avg_recall = 0
        avg_precision = 0

    max_recall = max(max_recall, avg_recall)
    max_prec = max(max_prec, avg_precision)
    print(f"Recall@{K}: {avg_recall:.4f} - max: {max_recall:.4f}")
    print(f"Precision@{K}: {avg_precision:.4f} - max: {max_prec:.4f}")
# Out:
# 1/100
# Training set: 57,449 ratings
# Test set: 76,045 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 423
# 100%|██████████| 423/423 [00:14<00:00, 29.41it/s]
# 16.1827 seconds
# Recall@50: 0.1778 - max: 0.1778
# Precision@50: 0.3557 - max: 0.3557
# 2/100
# Training set: 59,767 ratings
# Test set: 77,501 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 441
# 100%|██████████| 441/441 [00:15<00:00, 29.23it/s]
# 17.1506 seconds
# Recall@50: 0.1700 - max: 0.1778
# Precision@50: 0.3400 - max: 0.3557
# 3/100
# Training set: 47,312 ratings
# Test set: 74,921 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 406
# 100%|██████████| 406/406 [00:08<00:00, 48.55it/s]
# 9.6433 seconds
# Recall@50: 0.1732 - max: 0.1778
# Precision@50: 0.3464 - max: 0.3557
# 4/100
# Training set: 50,344 ratings
# Test set: 76,194 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 407
# 100%|██████████| 407/407 [00:10<00:00, 40.66it/s]
# 11.3961 seconds
# Recall@50: 0.1819 - max: 0.1819
# Precision@50: 0.3638 - max: 0.3638
# 5/100
# Training set: 57,209 ratings
# Test set: 76,266 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 433
# 100%|██████████| 433/433 [00:13<00:00, 32.90it/s]
# 14.8228 seconds
# Recall@50: 0.1650 - max: 0.1819
# Precision@50: 0.3300 - max: 0.3638
# 6/100
# Training set: 51,502 ratings
# Test set: 75,785 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 421
# 100%|██████████| 421/421 [00:12<00:00, 34.00it/s]
# 14.0204 seconds
# Recall@50: 0.1788 - max: 0.1819
# Precision@50: 0.3576 - max: 0.3638
# 7/100
# Training set: 48,818 ratings
# Test set: 75,346 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 405
# 100%|██████████| 405/405 [00:09<00:00, 44.34it/s]
# 10.5320 seconds
# Recall@50: 0.1700 - max: 0.1819
# Precision@50: 0.3400 - max: 0.3638
# 8/100
# Training set: 53,814 ratings
# Test set: 75,236 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 393
# 100%|██████████| 393/393 [00:14<00:00, 26.55it/s]
# 16.7859 seconds
# Recall@50: 0.1729 - max: 0.1819
# Precision@50: 0.3458 - max: 0.3638
# 9/100
# Training set: 47,724 ratings
# Test set: 74,825 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 400
# 100%|██████████| 400/400 [00:10<00:00, 38.39it/s]
# 11.8348 seconds
# Recall@50: 0.1691 - max: 0.1819
# Precision@50: 0.3383 - max: 0.3638
# 10/100
# Training set: 52,591 ratings
# Test set: 75,769 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 408
# 100%|██████████| 408/408 [00:13<00:00, 31.20it/s]
# 14.6128 seconds
# Recall@50: 0.1707 - max: 0.1819
# Precision@50: 0.3413 - max: 0.3638
# 11/100
# Training set: 52,100 ratings
# Test set: 75,848 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 421
# 100%|██████████| 421/421 [00:11<00:00, 35.55it/s]
# 13.3929 seconds
# Recall@50: 0.1759 - max: 0.1819
# Precision@50: 0.3519 - max: 0.3638
# 12/100
# Training set: 57,390 ratings
# Test set: 77,299 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 432
# 100%|██████████| 432/432 [00:15<00:00, 28.31it/s]
# 17.5385 seconds
# Recall@50: 0.1782 - max: 0.1819
# Precision@50: 0.3565 - max: 0.3638
# 13/100
# Training set: 48,405 ratings
# Test set: 74,427 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 401
# 100%|██████████| 401/401 [00:09<00:00, 42.43it/s]
# 10.7889 seconds
# Recall@50: 0.1784 - max: 0.1819
# Precision@50: 0.3568 - max: 0.3638
# 14/100
# Training set: 48,382 ratings
# Test set: 75,465 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 412
# 100%|██████████| 412/412 [00:10<00:00, 40.22it/s]
# 11.8525 seconds
# Recall@50: 0.1844 - max: 0.1844
# Precision@50: 0.3689 - max: 0.3689
# 15/100
# Training set: 53,679 ratings
# Test set: 76,168 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 427
# 100%|██████████| 427/427 [00:12<00:00, 35.28it/s]
# 13.6188 seconds
# Recall@50: 0.1456 - max: 0.1844
# Precision@50: 0.2913 - max: 0.3689
# 16/100
# Training set: 50,431 ratings
# Test set: 75,415 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 404
# 100%|██████████| 404/404 [00:12<00:00, 33.31it/s]
# 13.7462 seconds
# Recall@50: 0.1791 - max: 0.1844
# Precision@50: 0.3582 - max: 0.3689
# 17/100
# Training set: 56,822 ratings
# Test set: 76,042 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 420
# 100%|██████████| 420/420 [00:13<00:00, 31.60it/s]
# 14.7588 seconds
# Recall@50: 0.1833 - max: 0.1844
# Precision@50: 0.3667 - max: 0.3689
# 18/100
# Training set: 51,098 ratings
# Test set: 75,701 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 411
# 100%|██████████| 411/411 [00:09<00:00, 42.48it/s]
# 11.0839 seconds
# Recall@50: 0.1636 - max: 0.1844
# Precision@50: 0.3271 - max: 0.3689
# 19/100
# Training set: 61,179 ratings
# Test set: 75,635 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 427
# 100%|██████████| 427/427 [00:12<00:00, 33.09it/s]
# 14.4383 seconds
# Recall@50: 0.1565 - max: 0.1844
# Precision@50: 0.3130 - max: 0.3689
# 20/100
# Training set: 56,352 ratings
# Test set: 75,509 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 423
# 100%|██████████| 423/423 [00:12<00:00, 33.68it/s]
# 14.2616 seconds
# Recall@50: 0.1576 - max: 0.1844
# Precision@50: 0.3152 - max: 0.3689
# 21/100
# Training set: 52,171 ratings
# Test set: 75,985 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 416
# 100%|██████████| 416/416 [00:10<00:00, 38.64it/s]
# 12.1088 seconds
# Recall@50: 0.1589 - max: 0.1844
# Precision@50: 0.3179 - max: 0.3689
# 22/100
# Training set: 57,191 ratings
# Test set: 77,480 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 443
# 100%|██████████| 443/443 [00:11<00:00, 40.17it/s]
# 12.5872 seconds
# Recall@50: 0.1629 - max: 0.1844
# Precision@50: 0.3257 - max: 0.3689
# 23/100
# Training set: 60,024 ratings
# Test set: 77,289 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 459
# 100%|██████████| 459/459 [00:11<00:00, 40.61it/s]
# 13.0705 seconds
# Recall@50: 0.1636 - max: 0.1844
# Precision@50: 0.3273 - max: 0.3689
# 24/100
# Training set: 55,126 ratings
# Test set: 75,597 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 404
# 100%|██████████| 404/404 [00:11<00:00, 36.19it/s]
# 12.6550 seconds
# Recall@50: 0.2043 - max: 0.2043
# Precision@50: 0.4086 - max: 0.4086
# 25/100
# Training set: 50,665 ratings
# Test set: 74,967 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 399
# 100%|██████████| 399/399 [00:09<00:00, 40.75it/s]
# 11.0885 seconds
# Recall@50: 0.1442 - max: 0.2043
# Precision@50: 0.2884 - max: 0.4086
# 26/100
# Training set: 55,522 ratings
# Test set: 76,115 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 415
# 100%|██████████| 415/415 [00:12<00:00, 32.36it/s]
# 14.3302 seconds
# Recall@50: 0.1738 - max: 0.2043
# Precision@50: 0.3476 - max: 0.4086
# 27/100
# Training set: 55,073 ratings
# Test set: 76,219 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 430
# 100%|██████████| 430/430 [00:10<00:00, 42.43it/s]
# 11.4285 seconds
# Recall@50: 0.1792 - max: 0.2043
# Precision@50: 0.3583 - max: 0.4086
# 28/100
# Training set: 57,492 ratings
# Test set: 76,733 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 427
# 100%|██████████| 427/427 [00:12<00:00, 33.21it/s]
# 14.4041 seconds
# Recall@50: 0.1826 - max: 0.2043
# Precision@50: 0.3653 - max: 0.4086
# 29/100
# Training set: 55,130 ratings
# Test set: 75,574 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 415
# 100%|██████████| 415/415 [00:12<00:00, 33.45it/s]
# 14.0901 seconds
# Recall@50: 0.2115 - max: 0.2115
# Precision@50: 0.4230 - max: 0.4230
# 30/100
# Training set: 56,926 ratings
# Test set: 76,038 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 411
# 100%|██████████| 411/411 [00:12<00:00, 32.99it/s]
# 14.2174 seconds
# Recall@50: 0.1675 - max: 0.2115
# Precision@50: 0.3350 - max: 0.4230
# 31/100
# Training set: 48,009 ratings
# Test set: 75,843 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 400
# 100%|██████████| 400/400 [00:07<00:00, 52.91it/s]
# 8.6394 seconds
# Recall@50: 0.1518 - max: 0.2115
# Precision@50: 0.3035 - max: 0.4230
# 32/100
# Training set: 56,599 ratings
# Test set: 76,806 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 433
# 100%|██████████| 433/433 [00:11<00:00, 38.42it/s]
# 12.8686 seconds
# Recall@50: 0.1923 - max: 0.2115
# Precision@50: 0.3845 - max: 0.4230
# 33/100
# Training set: 53,814 ratings
# Test set: 75,561 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 408
# 100%|██████████| 408/408 [00:10<00:00, 39.12it/s]
# 11.7209 seconds
# Recall@50: 0.1669 - max: 0.2115
# Precision@50: 0.3338 - max: 0.4230
# 34/100
# Training set: 49,175 ratings
# Test set: 75,780 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 408
# 100%|██████████| 408/408 [00:08<00:00, 46.10it/s]
# 10.1653 seconds
# Recall@50: 0.1964 - max: 0.2115
# Precision@50: 0.3927 - max: 0.4230
# 35/100
# Training set: 53,419 ratings
# Test set: 77,670 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 441
# 100%|██████████| 441/441 [00:09<00:00, 44.59it/s]
# 11.2372 seconds
# Recall@50: 0.1696 - max: 0.2115
# Precision@50: 0.3392 - max: 0.4230
# 36/100
# Training set: 55,582 ratings
# Test set: 76,028 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 409
# 100%|██████████| 409/409 [00:11<00:00, 34.98it/s]
# 13.4628 seconds
# Recall@50: 0.1812 - max: 0.2115
# Precision@50: 0.3624 - max: 0.4230
# 37/100
# Training set: 52,392 ratings
# Test set: 75,926 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 412
# 100%|██████████| 412/412 [00:11<00:00, 36.06it/s]
# 13.0925 seconds
# Recall@50: 0.1576 - max: 0.2115
# Precision@50: 0.3152 - max: 0.4230
# 38/100
# Training set: 55,625 ratings
# Test set: 77,494 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 451
# 100%|██████████| 451/451 [00:10<00:00, 42.94it/s]
# 12.0730 seconds
# Recall@50: 0.1713 - max: 0.2115
# Precision@50: 0.3426 - max: 0.4230
# 39/100
# Training set: 52,319 ratings
# Test set: 75,679 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 400
# 100%|██████████| 400/400 [00:13<00:00, 29.18it/s]
# 15.5462 seconds
# Recall@50: 0.1521 - max: 0.2115
# Precision@50: 0.3042 - max: 0.4230
# 40/100
# Training set: 52,273 ratings
# Test set: 76,071 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 412
# 100%|██████████| 412/412 [00:11<00:00, 35.17it/s]
# 13.0369 seconds
# Recall@50: 0.1771 - max: 0.2115
# Precision@50: 0.3542 - max: 0.4230
# 41/100
# Training set: 53,018 ratings
# Test set: 76,366 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 425
# 100%|██████████| 425/425 [00:10<00:00, 42.32it/s]
# 11.4230 seconds
# Recall@50: 0.1624 - max: 0.2115
# Precision@50: 0.3248 - max: 0.4230
# 42/100
# Training set: 57,738 ratings
# Test set: 77,341 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 442
# 100%|██████████| 442/442 [00:10<00:00, 40.73it/s]
# 12.2113 seconds
# Recall@50: 0.1653 - max: 0.2115
# Precision@50: 0.3306 - max: 0.4230
# 43/100
# Training set: 61,433 ratings
# Test set: 75,699 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 421
# 100%|██████████| 421/421 [00:12<00:00, 33.97it/s]
# 13.9405 seconds
# Recall@50: 0.1569 - max: 0.2115
# Precision@50: 0.3138 - max: 0.4230
# 44/100
# Training set: 53,112 ratings
# Test set: 76,407 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 418
# 100%|██████████| 418/418 [00:13<00:00, 30.30it/s]
# 15.0613 seconds
# Recall@50: 0.1642 - max: 0.2115
# Precision@50: 0.3284 - max: 0.4230
# 45/100
# Training set: 58,965 ratings
# Test set: 76,358 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 418
# 100%|██████████| 418/418 [00:12<00:00, 32.40it/s]
# 14.3972 seconds
# Recall@50: 0.1563 - max: 0.2115
# Precision@50: 0.3126 - max: 0.4230
# 46/100
# Training set: 58,342 ratings
# Test set: 76,703 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 437
# 100%|██████████| 437/437 [00:11<00:00, 38.75it/s]
# 12.7166 seconds
# Recall@50: 0.1950 - max: 0.2115
# Precision@50: 0.3900 - max: 0.4230
# 47/100
# Training set: 54,629 ratings
# Test set: 76,678 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 422
# 100%|██████████| 422/422 [00:09<00:00, 44.52it/s]
# 11.0729 seconds
# Recall@50: 0.1921 - max: 0.2115
# Precision@50: 0.3842 - max: 0.4230
# 48/100
# Training set: 54,388 ratings
# Test set: 75,945 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 429
# 100%|██████████| 429/429 [00:10<00:00, 42.42it/s]
# 11.5801 seconds
# Recall@50: 0.1586 - max: 0.2115
# Precision@50: 0.3171 - max: 0.4230
# 49/100
# Training set: 55,299 ratings
# Test set: 75,952 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 417
# 100%|██████████| 417/417 [00:11<00:00, 36.17it/s]
# 13.4178 seconds
# Recall@50: 0.1506 - max: 0.2115
# Precision@50: 0.3013 - max: 0.4230
# 50/100
# Training set: 50,520 ratings
# Test set: 76,081 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 421
# 100%|██████████| 421/421 [00:08<00:00, 49.65it/s]
# 9.7350 seconds
# Recall@50: 0.1783 - max: 0.2115
# Precision@50: 0.3567 - max: 0.4230
# 51/100
# Training set: 48,933 ratings
# Test set: 75,602 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 398
# 100%|██████████| 398/398 [00:08<00:00, 48.31it/s]
# 9.4509 seconds
# Recall@50: 0.1750 - max: 0.2115
# Precision@50: 0.3500 - max: 0.4230
# 52/100
# Training set: 60,293 ratings
# Test set: 76,937 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 435
# 100%|██████████| 435/435 [00:11<00:00, 36.35it/s]
# 13.5167 seconds
# Recall@50: 0.1492 - max: 0.2115
# Precision@50: 0.2983 - max: 0.4230
# 53/100
# Training set: 55,823 ratings
# Test set: 75,015 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 414
# 100%|██████████| 414/414 [00:10<00:00, 38.06it/s]
# 12.2820 seconds
# Recall@50: 0.1716 - max: 0.2115
# Precision@50: 0.3432 - max: 0.4230
# 54/100
# Training set: 49,043 ratings
# Test set: 75,101 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 395
# 100%|██████████| 395/395 [00:08<00:00, 48.48it/s]
# 9.3002 seconds
# Recall@50: 0.1900 - max: 0.2115
# Precision@50: 0.3800 - max: 0.4230
# 55/100
# Training set: 53,870 ratings
# Test set: 75,363 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 399
# 100%|██████████| 399/399 [00:09<00:00, 42.43it/s]
# 10.6739 seconds
# Recall@50: 0.1983 - max: 0.2115
# Precision@50: 0.3967 - max: 0.4230
# 56/100
# Training set: 53,102 ratings
# Test set: 75,150 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 399
# 100%|██████████| 399/399 [00:08<00:00, 45.42it/s]
# 10.1999 seconds
# Recall@50: 0.1812 - max: 0.2115
# Precision@50: 0.3623 - max: 0.4230
# 57/100
# Training set: 52,052 ratings
# Test set: 74,943 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 408
# 100%|██████████| 408/408 [00:11<00:00, 34.45it/s]
# 13.4420 seconds
# Recall@50: 0.1621 - max: 0.2115
# Precision@50: 0.3242 - max: 0.4230
# 58/100
# Training set: 45,622 ratings
# Test set: 75,033 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 386
# 100%|██████████| 386/386 [00:07<00:00, 48.85it/s]
# 9.1321 seconds
# Recall@50: 0.1850 - max: 0.2115
# Precision@50: 0.3700 - max: 0.4230
# 59/100
# Training set: 49,652 ratings
# Test set: 76,247 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 418
# 100%|██████████| 418/418 [00:07<00:00, 52.53it/s]
# 9.0990 seconds
# Recall@50: 0.1639 - max: 0.2115
# Precision@50: 0.3279 - max: 0.4230
# 60/100
# Training set: 51,354 ratings
# Test set: 77,025 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 432
# 100%|██████████| 432/432 [00:09<00:00, 47.83it/s]
# 10.2398 seconds
# Recall@50: 0.1955 - max: 0.2115
# Precision@50: 0.3910 - max: 0.4230
# 61/100
# Training set: 48,632 ratings
# Test set: 76,250 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 421
# 100%|██████████| 421/421 [00:08<00:00, 49.16it/s]
# 9.7297 seconds
# Recall@50: 0.1592 - max: 0.2115
# Precision@50: 0.3184 - max: 0.4230
# 62/100
# Training set: 58,514 ratings
# Test set: 75,958 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 411
# 100%|██████████| 411/411 [00:12<00:00, 33.80it/s]
# 13.6692 seconds
# Recall@50: 0.1821 - max: 0.2115
# Precision@50: 0.3642 - max: 0.4230
# 63/100
# Training set: 54,531 ratings
# Test set: 76,936 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 431
# 100%|██████████| 431/431 [00:09<00:00, 45.58it/s]
# 10.8286 seconds
# Recall@50: 0.1896 - max: 0.2115
# Precision@50: 0.3791 - max: 0.4230
# 64/100
# Training set: 54,218 ratings
# Test set: 76,378 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 438
# 100%|██████████| 438/438 [00:10<00:00, 42.86it/s]
# 11.6162 seconds
# Recall@50: 0.1893 - max: 0.2115
# Precision@50: 0.3786 - max: 0.4230
# 65/100
# Training set: 49,770 ratings
# Test set: 75,522 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 401
# 100%|██████████| 401/401 [00:08<00:00, 45.97it/s]
# 9.9904 seconds
# Recall@50: 0.1891 - max: 0.2115
# Precision@50: 0.3782 - max: 0.4230
# 66/100
# Training set: 54,081 ratings
# Test set: 76,993 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 435
# 100%|██████████| 435/435 [00:09<00:00, 45.75it/s]
# 10.8312 seconds
# Recall@50: 0.1920 - max: 0.2115
# Precision@50: 0.3840 - max: 0.4230
# 67/100
# Training set: 55,755 ratings
# Test set: 75,527 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 406
# 100%|██████████| 406/406 [00:11<00:00, 35.49it/s]
# 12.9375 seconds
# Recall@50: 0.1578 - max: 0.2115
# Precision@50: 0.3156 - max: 0.4230
# 68/100
# Training set: 54,639 ratings
# Test set: 76,012 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 417
# 100%|██████████| 417/417 [00:09<00:00, 42.07it/s]
# 11.2860 seconds
# Recall@50: 0.1563 - max: 0.2115
# Precision@50: 0.3127 - max: 0.4230
# 69/100
# Training set: 51,007 ratings
# Test set: 76,120 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 403
# 100%|██████████| 403/403 [00:08<00:00, 45.62it/s]
# 10.0776 seconds
# Recall@50: 0.1606 - max: 0.2115
# Precision@50: 0.3211 - max: 0.4230
# 70/100
# Training set: 53,229 ratings
# Test set: 75,875 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 413
# 100%|██████████| 413/413 [00:12<00:00, 32.14it/s]
# 14.4416 seconds
# Recall@50: 0.1859 - max: 0.2115
# Precision@50: 0.3719 - max: 0.4230
# 71/100
# Training set: 56,481 ratings
# Test set: 74,385 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 400
# 100%|██████████| 400/400 [00:12<00:00, 31.51it/s]
# 14.2564 seconds
# Recall@50: 0.1640 - max: 0.2115
# Precision@50: 0.3280 - max: 0.4230
# 72/100
# Training set: 57,233 ratings
# Test set: 77,054 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 429
# 100%|██████████| 429/429 [00:12<00:00, 34.62it/s]
# 14.3276 seconds
# Recall@50: 0.1895 - max: 0.2115
# Precision@50: 0.3789 - max: 0.4230
# 73/100
# Training set: 56,140 ratings
# Test set: 77,217 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 430
# 100%|██████████| 430/430 [00:11<00:00, 37.17it/s]
# 13.5735 seconds
# Recall@50: 0.1527 - max: 0.2115
# Precision@50: 0.3055 - max: 0.4230
# 74/100
# Training set: 58,001 ratings
# Test set: 75,187 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 408
# 100%|██████████| 408/408 [00:11<00:00, 36.02it/s]
# 12.7199 seconds
# Recall@50: 0.1725 - max: 0.2115
# Precision@50: 0.3450 - max: 0.4230
# 75/100
# Training set: 53,861 ratings
# Test set: 75,563 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 422
# 100%|██████████| 422/422 [00:10<00:00, 41.98it/s]
# 11.4891 seconds
# Recall@50: 0.1489 - max: 0.2115
# Precision@50: 0.2978 - max: 0.4230
# 76/100
# Training set: 50,247 ratings
# Test set: 76,573 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 409
# 100%|██████████| 409/409 [00:09<00:00, 45.31it/s]
# 10.4498 seconds
# Recall@50: 0.1648 - max: 0.2115
# Precision@50: 0.3296 - max: 0.4230
# 77/100
# Training set: 54,833 ratings
# Test set: 76,393 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 419
# 100%|██████████| 419/419 [00:11<00:00, 35.39it/s]
# 13.4577 seconds
# Recall@50: 0.1786 - max: 0.2115
# Precision@50: 0.3571 - max: 0.4230
# 78/100
# Training set: 53,914 ratings
# Test set: 74,665 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 396
# 100%|██████████| 396/396 [00:11<00:00, 34.04it/s]
# 13.2570 seconds
# Recall@50: 0.1885 - max: 0.2115
# Precision@50: 0.3770 - max: 0.4230
# 79/100
# Training set: 56,250 ratings
# Test set: 77,124 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 444
# 100%|██████████| 444/444 [00:10<00:00, 43.63it/s]
# 11.4831 seconds
# Recall@50: 0.1647 - max: 0.2115
# Precision@50: 0.3294 - max: 0.4230
# 80/100
# Training set: 53,475 ratings
# Test set: 75,817 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 413
# 100%|██████████| 413/413 [00:12<00:00, 32.21it/s]
# 14.7734 seconds
# Recall@50: 0.1611 - max: 0.2115
# Precision@50: 0.3221 - max: 0.4230
# 81/100
# Training set: 57,640 ratings
# Test set: 76,800 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 427
# 100%|██████████| 427/427 [00:11<00:00, 36.49it/s]
# 13.1063 seconds
# Recall@50: 0.1550 - max: 0.2115
# Precision@50: 0.3100 - max: 0.4230
# 82/100
# Training set: 55,400 ratings
# Test set: 76,173 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 415
# 100%|██████████| 415/415 [00:11<00:00, 37.67it/s]
# 12.5442 seconds
# Recall@50: 0.1773 - max: 0.2115
# Precision@50: 0.3545 - max: 0.4230
# 83/100
# Training set: 55,509 ratings
# Test set: 77,047 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 443
# 100%|██████████| 443/443 [00:09<00:00, 45.47it/s]
# 11.0522 seconds
# Recall@50: 0.1668 - max: 0.2115
# Precision@50: 0.3336 - max: 0.4230
# 84/100
# Training set: 56,453 ratings
# Test set: 76,543 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 451
# 100%|██████████| 451/451 [00:09<00:00, 48.54it/s]
# 10.5510 seconds
# Recall@50: 0.1712 - max: 0.2115
# Precision@50: 0.3423 - max: 0.4230
# 85/100
# Training set: 54,974 ratings
# Test set: 75,600 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 408
# 100%|██████████| 408/408 [00:09<00:00, 41.16it/s]
# 11.2102 seconds
# Recall@50: 0.1629 - max: 0.2115
# Precision@50: 0.3257 - max: 0.4230
# 86/100
# Training set: 52,755 ratings
# Test set: 77,614 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 437
# 100%|██████████| 437/437 [00:10<00:00, 43.01it/s]
# 11.5838 seconds
# Recall@50: 0.1555 - max: 0.2115
# Precision@50: 0.3109 - max: 0.4230
# 87/100
# Training set: 55,311 ratings
# Test set: 75,542 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 404
# 100%|██████████| 404/404 [00:11<00:00, 35.44it/s]
# 12.8861 seconds
# Recall@50: 0.1743 - max: 0.2115
# Precision@50: 0.3486 - max: 0.4230
# 88/100
# Training set: 52,611 ratings
# Test set: 75,926 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 404
# 100%|██████████| 404/404 [00:10<00:00, 36.99it/s]
# 12.3631 seconds
# Recall@50: 0.1575 - max: 0.2115
# Precision@50: 0.3150 - max: 0.4230
# 89/100
# Training set: 54,423 ratings
# Test set: 76,237 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 417
# 100%|██████████| 417/417 [00:10<00:00, 40.22it/s]
# 11.8746 seconds
# Recall@50: 0.1480 - max: 0.2115
# Precision@50: 0.2960 - max: 0.4230
# 90/100
# Training set: 53,931 ratings
# Test set: 76,485 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 431
# 100%|██████████| 431/431 [00:10<00:00, 41.51it/s]
# 11.8086 seconds
# Recall@50: 0.1700 - max: 0.2115
# Precision@50: 0.3400 - max: 0.4230
# 91/100
# Training set: 51,571 ratings
# Test set: 75,386 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 391
# 100%|██████████| 391/391 [00:12<00:00, 30.33it/s]
# 14.6773 seconds
# Recall@50: 0.1800 - max: 0.2115
# Precision@50: 0.3600 - max: 0.4230
# 92/100
# Training set: 49,537 ratings
# Test set: 75,992 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 411
# 100%|██████████| 411/411 [00:07<00:00, 52.44it/s]
# 9.0672 seconds
# Recall@50: 0.1612 - max: 0.2115
# Precision@50: 0.3223 - max: 0.4230
# 93/100
# Training set: 57,285 ratings
# Test set: 76,601 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 436
# 100%|██████████| 436/436 [00:11<00:00, 36.70it/s]
# 13.4204 seconds
# Recall@50: 0.1415 - max: 0.2115
# Precision@50: 0.2830 - max: 0.4230
# 94/100
# Training set: 54,644 ratings
# Test set: 74,508 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 387
# 100%|██████████| 387/387 [00:12<00:00, 30.34it/s]
# 14.3473 seconds
# Recall@50: 0.1844 - max: 0.2115
# Precision@50: 0.3689 - max: 0.4230
# 95/100
# Training set: 57,617 ratings
# Test set: 77,412 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 429
# 100%|██████████| 429/429 [00:11<00:00, 37.70it/s]
# 12.8297 seconds
# Recall@50: 0.1770 - max: 0.2115
# Precision@50: 0.3540 - max: 0.4230
# 96/100
# Training set: 59,135 ratings
# Test set: 77,405 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 442
# 100%|██████████| 442/442 [00:11<00:00, 37.62it/s]
# 13.3637 seconds
# Recall@50: 0.1886 - max: 0.2115
# Precision@50: 0.3771 - max: 0.4230
# 97/100
# Training set: 55,480 ratings
# Test set: 75,624 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 418
# 100%|██████████| 418/418 [00:10<00:00, 38.00it/s]
# 12.5294 seconds
# Recall@50: 0.2010 - max: 0.2115
# Precision@50: 0.4021 - max: 0.4230
# 98/100
# Training set: 60,620 ratings
# Test set: 76,425 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 434
# 100%|██████████| 434/434 [00:21<00:00, 20.42it/s]
# 23.2665 seconds
# Recall@50: 0.1810 - max: 0.2115
# Precision@50: 0.3620 - max: 0.4230
# 99/100
# Training set: 52,893 ratings
# Test set: 75,322 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 409
# 100%|██████████| 409/409 [00:13<00:00, 30.78it/s]
# 14.9486 seconds
# Recall@50: 0.1852 - max: 0.2115
# Precision@50: 0.3704 - max: 0.4230
# 100/100
# Training set: 53,746 ratings
# Test set: 76,134 ratings (Leave-100-out)
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 430
# 100%|██████████| 430/430 [00:13<00:00, 32.01it/s]
# 16.3158 seconds
# Recall@50: 0.1858 - max: 0.2115
# Precision@50: 0.3717 - max: 0.4230

# %%
leave_k_out = 100
n_users = 10000

# selected_user_ids = np.random.choice(selected_users['x'].unique(), 1000, replace=False)
all_users = ratings['userId'].unique()
selected_user_ids = np.random.choice(all_users, size=n_users, replace=False)
print(f"Selected {len(selected_user_ids)} unique users")

filtered_ratings = ratings[ratings['userId'].isin(selected_user_ids)]
print(f"Original ratings shape: {ratings.shape}")
print(f"Filtered ratings shape: {filtered_ratings.shape}")

filtered_ratings_sorted = filtered_ratings.sort_values(['userId', 'timestamp'])

train_ratings = filtered_ratings_sorted.groupby('userId').apply(lambda x: x.iloc[:-leave_k_out] if len(x) > leave_k_out else pd.DataFrame()).reset_index(drop=True)
test_ratings = filtered_ratings_sorted.groupby('userId').tail(leave_k_out)

print(f"Training set: {train_ratings.shape[0]:,} ratings")
print(f"Test set: {test_ratings.shape[0]:,} ratings")

print("Training implicit feedback Markov chain...")
model = ImplicitMarkovChain(alpha=2.0)
start = time.time()
model.build_transition_matrix_efficient(train_ratings, sample_fraction=1)
print(f"{time.time() - start:.4f} seconds")
# Out:
# Selected 10000 unique users
# Original ratings shape: (10246362, 4)
# Filtered ratings shape: (1307853, 4)
# Training set: 542,327 ratings
# Test set: 765,526 ratings
# Training implicit feedback Markov chain...
# Processing user ratings...
# User Groups: 4234
# 100%|██████████| 4234/4234 [04:05<00:00, 17.25it/s]
# 253.0982 seconds

# %%
# from curses import window

K = 50
total_recall = 0
users_not_considered = 0
recalls = []
total_precision = 0
user_recommendations = {}
train_ratings_sorted = train_ratings.sort_values(['userId', 'timestamp'])

for user_id in selected_user_ids:
    user_data = train_ratings_sorted[train_ratings_sorted['userId'] == user_id]
    user_training_samples = len(user_data)
    
    candidate_scores = {}
    
    window_size = 0
    while len(candidate_scores) < K and window_size < len(user_data):
        # print(window_size)
        window_size += K
        additional_movies = user_data['movieId'].tail(window_size).head(K).tolist()

        
        for movie_id in additional_movies:
            probabilities = model.transition_matrix[model.movie_to_idx[movie_id]]
            top_indices = np.argsort(probabilities)[-(K):][::-1]
            
            movies_added = 0
            for i in top_indices:
                # print(f"movies added: {movies_added}")
                # if movies_added >= K:
                #     break
                    
                candidate_movie_id = model.idx_to_movie[i]
                candidate_prob = probabilities[i]
                
                # Skip if user has already rated this movie
                if candidate_movie_id in user_data['movieId'].values:
                    continue
                    
                # Keep the highest probability for each movie
                if candidate_movie_id not in candidate_scores:
                    candidate_scores[candidate_movie_id] = candidate_prob
                    movies_added += 1
                elif candidate_prob > candidate_scores[candidate_movie_id]:
                    candidate_scores[candidate_movie_id] = candidate_prob
                    
            # if len(candidate_scores) >= K:
            #     break


    top_movies = sorted(candidate_scores.items(), key=lambda x: x[1], reverse=True)[:K]
    if len(top_movies) < K:
        users_not_considered += 1
        continue
    candidate_movies = [movie_id for movie_id, score in top_movies]
    recommended_movies = set(candidate_movies)
    user_test_ratings = test_ratings[test_ratings['userId'] == user_id]
    relevant_movies = set(user_test_ratings['movieId'].tolist())
    
    # validation
    hits = relevant_movies.intersection(recommended_movies)
    
    user_recall = 0
    if len(relevant_movies) > 0:
        user_recall = len(hits) / len(relevant_movies)
        total_recall += user_recall    
    recalls.append(user_recall)
    print(f"userid: {user_id} - len(top_movies): {len(top_movies)} - training_data: {len(user_data)} - test_data: {len(relevant_movies)} - window: {window_size} - hits: {len(hits)} recall: {user_recall}")

    if len(recommended_movies) > 0:
        user_precision = len(hits) / len(recommended_movies)
        total_precision += user_precision


print(f"total users: {len(selected_user_ids)} - users not consid. {users_not_considered} - total_recall: {total_recall}")
avg_recall = total_recall / (len(selected_user_ids)-users_not_considered)
avg_precision = total_precision / ((len(selected_user_ids)-users_not_considered)*K)

print("\n=== Final Results ===")
# print(f"Total users processed: {len(selected_user_ids)}")
print(f"Recall@{K}: {avg_recall:.4f}")
# print(f"Precision@{K}: {avg_precision:.4f}")
# Out:
# userid: 117305 - len(top_movies): 50 - training_data: 81 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 28943 - len(top_movies): 50 - training_data: 45 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 23301 - len(top_movies): 50 - training_data: 17 - test_data: 100 - window: 10 - hits: 34 recall: 0.34
# userid: 67749 - len(top_movies): 50 - training_data: 206 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 96468 - len(top_movies): 50 - training_data: 87 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 67629 - len(top_movies): 50 - training_data: 148 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 45958 - len(top_movies): 50 - training_data: 102 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 58606 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 33 recall: 0.33
# userid: 122589 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 37 recall: 0.37
# userid: 118022 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 34929 - len(top_movies): 50 - training_data: 120 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 79040 - len(top_movies): 50 - training_data: 40 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 94750 - len(top_movies): 50 - training_data: 536 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 67047 - len(top_movies): 50 - training_data: 73 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 82840 - len(top_movies): 50 - training_data: 13 - test_data: 100 - window: 10 - hits: 31 recall: 0.31
# userid: 107716 - len(top_movies): 50 - training_data: 10 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 63688 - len(top_movies): 50 - training_data: 43 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 127283 - len(top_movies): 50 - training_data: 25 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 108538 - len(top_movies): 50 - training_data: 90 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 3859 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 137151 - len(top_movies): 50 - training_data: 7 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 116479 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 29785 - len(top_movies): 50 - training_data: 25 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 37253 - len(top_movies): 50 - training_data: 243 - test_data: 100 - window: 10 - hits: 2 recall: 0.02
# userid: 137021 - len(top_movies): 50 - training_data: 24 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 26497 - len(top_movies): 50 - training_data: 149 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 76527 - len(top_movies): 50 - training_data: 89 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 54699 - len(top_movies): 50 - training_data: 111 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 112572 - len(top_movies): 50 - training_data: 252 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 108317 - len(top_movies): 50 - training_data: 78 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 78557 - len(top_movies): 50 - training_data: 70 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 59022 - len(top_movies): 50 - training_data: 90 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 67555 - len(top_movies): 50 - training_data: 129 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 59603 - len(top_movies): 50 - training_data: 83 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 7949 - len(top_movies): 50 - training_data: 87 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 70496 - len(top_movies): 50 - training_data: 17 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 102051 - len(top_movies): 50 - training_data: 16 - test_data: 100 - window: 10 - hits: 41 recall: 0.41
# userid: 12867 - len(top_movies): 50 - training_data: 28 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 47676 - len(top_movies): 50 - training_data: 12 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 68717 - len(top_movies): 50 - training_data: 142 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 7315 - len(top_movies): 50 - training_data: 79 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 14034 - len(top_movies): 50 - training_data: 432 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 2732 - len(top_movies): 50 - training_data: 149 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 115378 - len(top_movies): 50 - training_data: 131 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 23095 - len(top_movies): 50 - training_data: 233 - test_data: 100 - window: 10 - hits: 28 recall: 0.28
# userid: 47743 - len(top_movies): 50 - training_data: 7 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 102681 - len(top_movies): 50 - training_data: 23 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 109380 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 117362 - len(top_movies): 50 - training_data: 11 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 22821 - len(top_movies): 50 - training_data: 109 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 36204 - len(top_movies): 50 - training_data: 141 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 130819 - len(top_movies): 50 - training_data: 186 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 47796 - len(top_movies): 50 - training_data: 179 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 92357 - len(top_movies): 50 - training_data: 49 - test_data: 100 - window: 10 - hits: 28 recall: 0.28
# userid: 58327 - len(top_movies): 50 - training_data: 1 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 123958 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 100139 - len(top_movies): 50 - training_data: 58 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 120063 - len(top_movies): 50 - training_data: 128 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 68216 - len(top_movies): 50 - training_data: 7 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 122728 - len(top_movies): 50 - training_data: 2 - test_data: 100 - window: 10 - hits: 29 recall: 0.29
# userid: 78109 - len(top_movies): 50 - training_data: 56 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 9838 - len(top_movies): 50 - training_data: 142 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 64367 - len(top_movies): 50 - training_data: 63 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 105805 - len(top_movies): 50 - training_data: 33 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 1267 - len(top_movies): 50 - training_data: 109 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 38824 - len(top_movies): 50 - training_data: 72 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 16779 - len(top_movies): 50 - training_data: 49 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 96293 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 67182 - len(top_movies): 50 - training_data: 110 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 593 - len(top_movies): 50 - training_data: 75 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 97750 - len(top_movies): 50 - training_data: 225 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 33897 - len(top_movies): 50 - training_data: 51 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 132408 - len(top_movies): 50 - training_data: 14 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 137084 - len(top_movies): 50 - training_data: 47 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 48382 - len(top_movies): 50 - training_data: 302 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 68077 - len(top_movies): 50 - training_data: 158 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 86757 - len(top_movies): 50 - training_data: 17 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 75375 - len(top_movies): 50 - training_data: 193 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 81947 - len(top_movies): 50 - training_data: 49 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 47476 - len(top_movies): 50 - training_data: 386 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 61373 - len(top_movies): 50 - training_data: 50 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 80029 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 26 recall: 0.26
# userid: 47495 - len(top_movies): 50 - training_data: 66 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 1015 - len(top_movies): 50 - training_data: 101 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 28440 - len(top_movies): 50 - training_data: 65 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 77613 - len(top_movies): 50 - training_data: 173 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 111335 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 30159 - len(top_movies): 50 - training_data: 84 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 22466 - len(top_movies): 50 - training_data: 22 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 63768 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 50565 - len(top_movies): 50 - training_data: 27 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 79054 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 83638 - len(top_movies): 50 - training_data: 111 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 109091 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 91621 - len(top_movies): 50 - training_data: 180 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 4661 - len(top_movies): 50 - training_data: 53 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 55021 - len(top_movies): 50 - training_data: 3 - test_data: 100 - window: 10 - hits: 30 recall: 0.3
# userid: 87907 - len(top_movies): 50 - training_data: 52 - test_data: 100 - window: 10 - hits: 31 recall: 0.31
# userid: 21891 - len(top_movies): 50 - training_data: 20 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 108545 - len(top_movies): 50 - training_data: 12 - test_data: 100 - window: 10 - hits: 37 recall: 0.37
# userid: 85581 - len(top_movies): 50 - training_data: 162 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 40728 - len(top_movies): 50 - training_data: 93 - test_data: 100 - window: 10 - hits: 27 recall: 0.27
# userid: 81878 - len(top_movies): 50 - training_data: 282 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 102845 - len(top_movies): 50 - training_data: 100 - test_data: 100 - window: 10 - hits: 0 recall: 0.0
# userid: 24422 - len(top_movies): 50 - training_data: 54 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 101267 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 107474 - len(top_movies): 50 - training_data: 28 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 3968 - len(top_movies): 50 - training_data: 89 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 8249 - len(top_movies): 50 - training_data: 285 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 118598 - len(top_movies): 50 - training_data: 60 - test_data: 100 - window: 10 - hits: 26 recall: 0.26
# userid: 109399 - len(top_movies): 50 - training_data: 56 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 53231 - len(top_movies): 50 - training_data: 155 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 93431 - len(top_movies): 50 - training_data: 123 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 21718 - len(top_movies): 50 - training_data: 111 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 19258 - len(top_movies): 50 - training_data: 170 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 56260 - len(top_movies): 50 - training_data: 37 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 132808 - len(top_movies): 50 - training_data: 184 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 71074 - len(top_movies): 50 - training_data: 5 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 75627 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 27 recall: 0.27
# userid: 126168 - len(top_movies): 50 - training_data: 54 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 16676 - len(top_movies): 50 - training_data: 800 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 52065 - len(top_movies): 50 - training_data: 21 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 55302 - len(top_movies): 50 - training_data: 164 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 54875 - len(top_movies): 50 - training_data: 102 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 120773 - len(top_movies): 50 - training_data: 118 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 129910 - len(top_movies): 50 - training_data: 127 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 82044 - len(top_movies): 50 - training_data: 40 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 75719 - len(top_movies): 50 - training_data: 82 - test_data: 100 - window: 10 - hits: 2 recall: 0.02
# userid: 27245 - len(top_movies): 50 - training_data: 22 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 5257 - len(top_movies): 50 - training_data: 33 - test_data: 100 - window: 10 - hits: 28 recall: 0.28
# userid: 22525 - len(top_movies): 50 - training_data: 33 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 59378 - len(top_movies): 50 - training_data: 21 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 86430 - len(top_movies): 50 - training_data: 44 - test_data: 100 - window: 10 - hits: 34 recall: 0.34
# userid: 20652 - len(top_movies): 50 - training_data: 73 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 123810 - len(top_movies): 50 - training_data: 189 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 72495 - len(top_movies): 50 - training_data: 65 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 131665 - len(top_movies): 50 - training_data: 48 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 105623 - len(top_movies): 50 - training_data: 50 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 37948 - len(top_movies): 50 - training_data: 55 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 130508 - len(top_movies): 50 - training_data: 9 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 26335 - len(top_movies): 50 - training_data: 62 - test_data: 100 - window: 10 - hits: 28 recall: 0.28
# userid: 111285 - len(top_movies): 50 - training_data: 5 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 46251 - len(top_movies): 50 - training_data: 56 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 2335 - len(top_movies): 50 - training_data: 62 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 43304 - len(top_movies): 50 - training_data: 60 - test_data: 100 - window: 10 - hits: 32 recall: 0.32
# userid: 36994 - len(top_movies): 50 - training_data: 130 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 38727 - len(top_movies): 50 - training_data: 2 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 115353 - len(top_movies): 50 - training_data: 79 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 100020 - len(top_movies): 50 - training_data: 92 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 108458 - len(top_movies): 50 - training_data: 29 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 3508 - len(top_movies): 50 - training_data: 84 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 496 - len(top_movies): 50 - training_data: 38 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 81984 - len(top_movies): 50 - training_data: 34 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 133182 - len(top_movies): 50 - training_data: 36 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 132450 - len(top_movies): 50 - training_data: 83 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 25421 - len(top_movies): 50 - training_data: 47 - test_data: 100 - window: 10 - hits: 40 recall: 0.4
# userid: 60780 - len(top_movies): 50 - training_data: 24 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 63284 - len(top_movies): 50 - training_data: 111 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 69932 - len(top_movies): 50 - training_data: 5 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 115055 - len(top_movies): 50 - training_data: 207 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 26304 - len(top_movies): 50 - training_data: 166 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 39102 - len(top_movies): 50 - training_data: 262 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 137342 - len(top_movies): 50 - training_data: 141 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 124323 - len(top_movies): 50 - training_data: 33 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 54351 - len(top_movies): 50 - training_data: 253 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 137581 - len(top_movies): 50 - training_data: 31 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 57057 - len(top_movies): 50 - training_data: 55 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 22543 - len(top_movies): 50 - training_data: 28 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 98316 - len(top_movies): 50 - training_data: 24 - test_data: 100 - window: 10 - hits: 38 recall: 0.38
# userid: 88373 - len(top_movies): 50 - training_data: 413 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 39551 - len(top_movies): 50 - training_data: 108 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 120402 - len(top_movies): 50 - training_data: 242 - test_data: 100 - window: 10 - hits: 1 recall: 0.01
# userid: 136097 - len(top_movies): 50 - training_data: 55 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 40283 - len(top_movies): 50 - training_data: 23 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 109442 - len(top_movies): 50 - training_data: 42 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 43560 - len(top_movies): 50 - training_data: 55 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 94704 - len(top_movies): 50 - training_data: 63 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 14336 - len(top_movies): 50 - training_data: 54 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 119609 - len(top_movies): 50 - training_data: 79 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 8403 - len(top_movies): 50 - training_data: 74 - test_data: 100 - window: 10 - hits: 27 recall: 0.27
# userid: 48606 - len(top_movies): 50 - training_data: 111 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 71879 - len(top_movies): 50 - training_data: 37 - test_data: 100 - window: 10 - hits: 26 recall: 0.26
# userid: 134848 - len(top_movies): 50 - training_data: 45 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 103176 - len(top_movies): 50 - training_data: 31 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 84492 - len(top_movies): 50 - training_data: 62 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 102055 - len(top_movies): 50 - training_data: 225 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 77204 - len(top_movies): 50 - training_data: 33 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 101088 - len(top_movies): 50 - training_data: 25 - test_data: 100 - window: 10 - hits: 28 recall: 0.28
# userid: 71203 - len(top_movies): 50 - training_data: 61 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 65257 - len(top_movies): 50 - training_data: 27 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 116736 - len(top_movies): 50 - training_data: 59 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 27922 - len(top_movies): 50 - training_data: 46 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 31887 - len(top_movies): 50 - training_data: 249 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 106171 - len(top_movies): 50 - training_data: 12 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 120228 - len(top_movies): 50 - training_data: 11 - test_data: 100 - window: 10 - hits: 34 recall: 0.34
# userid: 84068 - len(top_movies): 50 - training_data: 126 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 108028 - len(top_movies): 50 - training_data: 132 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 22468 - len(top_movies): 50 - training_data: 23 - test_data: 100 - window: 10 - hits: 38 recall: 0.38
# userid: 84288 - len(top_movies): 50 - training_data: 127 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 51844 - len(top_movies): 50 - training_data: 13 - test_data: 100 - window: 10 - hits: 26 recall: 0.26
# userid: 38327 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 67642 - len(top_movies): 50 - training_data: 90 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 76599 - len(top_movies): 50 - training_data: 107 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 1426 - len(top_movies): 50 - training_data: 39 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 53272 - len(top_movies): 50 - training_data: 211 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 59203 - len(top_movies): 50 - training_data: 58 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 12402 - len(top_movies): 50 - training_data: 318 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 56962 - len(top_movies): 50 - training_data: 209 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 120932 - len(top_movies): 50 - training_data: 223 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 111690 - len(top_movies): 50 - training_data: 17 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 87163 - len(top_movies): 50 - training_data: 177 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 104911 - len(top_movies): 50 - training_data: 151 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 3821 - len(top_movies): 50 - training_data: 56 - test_data: 100 - window: 10 - hits: 39 recall: 0.39
# userid: 94897 - len(top_movies): 50 - training_data: 59 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 105640 - len(top_movies): 50 - training_data: 319 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 90839 - len(top_movies): 50 - training_data: 153 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 120249 - len(top_movies): 50 - training_data: 276 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 14859 - len(top_movies): 50 - training_data: 264 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 137018 - len(top_movies): 50 - training_data: 119 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 20763 - len(top_movies): 50 - training_data: 95 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 79450 - len(top_movies): 50 - training_data: 56 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 26402 - len(top_movies): 50 - training_data: 86 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 107574 - len(top_movies): 50 - training_data: 81 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 57950 - len(top_movies): 50 - training_data: 37 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 85304 - len(top_movies): 50 - training_data: 13 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 96875 - len(top_movies): 50 - training_data: 10 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 54530 - len(top_movies): 50 - training_data: 55 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 95221 - len(top_movies): 50 - training_data: 329 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 4965 - len(top_movies): 50 - training_data: 151 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 32656 - len(top_movies): 50 - training_data: 2 - test_data: 100 - window: 10 - hits: 29 recall: 0.29
# userid: 38074 - len(top_movies): 50 - training_data: 1 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 113838 - len(top_movies): 50 - training_data: 125 - test_data: 100 - window: 10 - hits: 41 recall: 0.41
# userid: 25596 - len(top_movies): 50 - training_data: 9 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 27213 - len(top_movies): 50 - training_data: 1 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 120005 - len(top_movies): 50 - training_data: 52 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 90488 - len(top_movies): 50 - training_data: 161 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 86862 - len(top_movies): 50 - training_data: 64 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 35573 - len(top_movies): 50 - training_data: 64 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 77715 - len(top_movies): 50 - training_data: 23 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 74437 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 28 recall: 0.28
# userid: 105384 - len(top_movies): 50 - training_data: 26 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 135905 - len(top_movies): 50 - training_data: 75 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 128561 - len(top_movies): 50 - training_data: 92 - test_data: 100 - window: 10 - hits: 1 recall: 0.01
# userid: 75494 - len(top_movies): 50 - training_data: 44 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 47787 - len(top_movies): 50 - training_data: 143 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 138081 - len(top_movies): 50 - training_data: 11 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 3239 - len(top_movies): 50 - training_data: 47 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 119811 - len(top_movies): 50 - training_data: 404 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 10962 - len(top_movies): 50 - training_data: 43 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 7107 - len(top_movies): 50 - training_data: 73 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 38791 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 29 recall: 0.29
# userid: 81910 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 74137 - len(top_movies): 50 - training_data: 78 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 64818 - len(top_movies): 50 - training_data: 59 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 24213 - len(top_movies): 50 - training_data: 128 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 25022 - len(top_movies): 50 - training_data: 5 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 25996 - len(top_movies): 50 - training_data: 13 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 124227 - len(top_movies): 50 - training_data: 360 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 8162 - len(top_movies): 50 - training_data: 45 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 18028 - len(top_movies): 50 - training_data: 54 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 88027 - len(top_movies): 50 - training_data: 65 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 62901 - len(top_movies): 50 - training_data: 74 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 122608 - len(top_movies): 50 - training_data: 92 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 96344 - len(top_movies): 50 - training_data: 70 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 35037 - len(top_movies): 50 - training_data: 467 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 26178 - len(top_movies): 50 - training_data: 29 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 76985 - len(top_movies): 50 - training_data: 31 - test_data: 100 - window: 10 - hits: 32 recall: 0.32
# userid: 120975 - len(top_movies): 50 - training_data: 23 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 121748 - len(top_movies): 50 - training_data: 2 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 55157 - len(top_movies): 50 - training_data: 8 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 17011 - len(top_movies): 50 - training_data: 253 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 93528 - len(top_movies): 50 - training_data: 248 - test_data: 100 - window: 10 - hits: 1 recall: 0.01
# userid: 4519 - len(top_movies): 50 - training_data: 89 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 110817 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 22983 - len(top_movies): 50 - training_data: 76 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 37428 - len(top_movies): 50 - training_data: 50 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 94815 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 919 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 88132 - len(top_movies): 50 - training_data: 80 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 52223 - len(top_movies): 50 - training_data: 89 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 12251 - len(top_movies): 50 - training_data: 45 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 79351 - len(top_movies): 50 - training_data: 31 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 92918 - len(top_movies): 50 - training_data: 244 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 18900 - len(top_movies): 50 - training_data: 334 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 43602 - len(top_movies): 50 - training_data: 40 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 19090 - len(top_movies): 50 - training_data: 24 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 99606 - len(top_movies): 50 - training_data: 170 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 138202 - len(top_movies): 50 - training_data: 86 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 75552 - len(top_movies): 50 - training_data: 55 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 17196 - len(top_movies): 50 - training_data: 43 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 113021 - len(top_movies): 50 - training_data: 3 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 85597 - len(top_movies): 50 - training_data: 86 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 285 - len(top_movies): 50 - training_data: 49 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 37045 - len(top_movies): 50 - training_data: 7 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 125826 - len(top_movies): 50 - training_data: 224 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 117501 - len(top_movies): 50 - training_data: 40 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 41355 - len(top_movies): 50 - training_data: 26 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 85492 - len(top_movies): 50 - training_data: 296 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 131327 - len(top_movies): 50 - training_data: 157 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 23962 - len(top_movies): 50 - training_data: 49 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 18348 - len(top_movies): 50 - training_data: 149 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 49708 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 92142 - len(top_movies): 50 - training_data: 132 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 47173 - len(top_movies): 50 - training_data: 76 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 110583 - len(top_movies): 50 - training_data: 46 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 84681 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 1 - len(top_movies): 50 - training_data: 50 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 31943 - len(top_movies): 50 - training_data: 72 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 53790 - len(top_movies): 50 - training_data: 143 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 31351 - len(top_movies): 50 - training_data: 5 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 31804 - len(top_movies): 50 - training_data: 86 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 38585 - len(top_movies): 50 - training_data: 159 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 136041 - len(top_movies): 50 - training_data: 31 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 118495 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 59409 - len(top_movies): 50 - training_data: 95 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 55282 - len(top_movies): 50 - training_data: 61 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 14053 - len(top_movies): 50 - training_data: 302 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 69715 - len(top_movies): 50 - training_data: 58 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 28225 - len(top_movies): 50 - training_data: 91 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 114087 - len(top_movies): 50 - training_data: 138 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 38346 - len(top_movies): 50 - training_data: 101 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 106676 - len(top_movies): 50 - training_data: 382 - test_data: 100 - window: 10 - hits: 1 recall: 0.01
# userid: 124189 - len(top_movies): 50 - training_data: 109 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 111130 - len(top_movies): 50 - training_data: 102 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 109642 - len(top_movies): 50 - training_data: 45 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 53607 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 56623 - len(top_movies): 50 - training_data: 46 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 123884 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 27 recall: 0.27
# userid: 130384 - len(top_movies): 50 - training_data: 152 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 46521 - len(top_movies): 50 - training_data: 29 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 125233 - len(top_movies): 50 - training_data: 149 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 123158 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 17220 - len(top_movies): 50 - training_data: 118 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 75327 - len(top_movies): 50 - training_data: 82 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 89314 - len(top_movies): 50 - training_data: 75 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 85360 - len(top_movies): 50 - training_data: 51 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 59680 - len(top_movies): 50 - training_data: 141 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 29727 - len(top_movies): 50 - training_data: 131 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 137949 - len(top_movies): 50 - training_data: 324 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 110476 - len(top_movies): 50 - training_data: 109 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 110182 - len(top_movies): 50 - training_data: 37 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 90028 - len(top_movies): 50 - training_data: 39 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 50381 - len(top_movies): 50 - training_data: 75 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 15432 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 132124 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 137657 - len(top_movies): 50 - training_data: 50 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 114698 - len(top_movies): 50 - training_data: 92 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 43533 - len(top_movies): 50 - training_data: 33 - test_data: 100 - window: 10 - hits: 32 recall: 0.32
# userid: 88898 - len(top_movies): 50 - training_data: 144 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 96622 - len(top_movies): 50 - training_data: 55 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 22611 - len(top_movies): 50 - training_data: 71 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 119575 - len(top_movies): 50 - training_data: 50 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 88397 - len(top_movies): 50 - training_data: 267 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 136989 - len(top_movies): 50 - training_data: 351 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 11579 - len(top_movies): 50 - training_data: 314 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 118060 - len(top_movies): 50 - training_data: 42 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 60749 - len(top_movies): 50 - training_data: 314 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 16696 - len(top_movies): 50 - training_data: 84 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 118193 - len(top_movies): 50 - training_data: 114 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 115640 - len(top_movies): 50 - training_data: 10 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 37999 - len(top_movies): 50 - training_data: 339 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 112541 - len(top_movies): 50 - training_data: 77 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 130338 - len(top_movies): 50 - training_data: 22 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 64552 - len(top_movies): 50 - training_data: 31 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 70945 - len(top_movies): 50 - training_data: 261 - test_data: 100 - window: 10 - hits: 2 recall: 0.02
# userid: 42900 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 54589 - len(top_movies): 50 - training_data: 10 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 56258 - len(top_movies): 50 - training_data: 22 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 114239 - len(top_movies): 50 - training_data: 75 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 43472 - len(top_movies): 50 - training_data: 61 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 488 - len(top_movies): 50 - training_data: 37 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 73019 - len(top_movies): 50 - training_data: 11 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 83948 - len(top_movies): 50 - training_data: 144 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 99895 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 17014 - len(top_movies): 50 - training_data: 351 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 131819 - len(top_movies): 50 - training_data: 36 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 26717 - len(top_movies): 50 - training_data: 133 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 17399 - len(top_movies): 50 - training_data: 3 - test_data: 100 - window: 10 - hits: 34 recall: 0.34
# userid: 71461 - len(top_movies): 50 - training_data: 25 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 2322 - len(top_movies): 50 - training_data: 86 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 130605 - len(top_movies): 50 - training_data: 154 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 106096 - len(top_movies): 50 - training_data: 57 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 38127 - len(top_movies): 50 - training_data: 78 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 94811 - len(top_movies): 50 - training_data: 47 - test_data: 100 - window: 10 - hits: 26 recall: 0.26
# userid: 984 - len(top_movies): 50 - training_data: 44 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 19318 - len(top_movies): 50 - training_data: 125 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 46121 - len(top_movies): 50 - training_data: 340 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 8645 - len(top_movies): 50 - training_data: 14 - test_data: 100 - window: 10 - hits: 31 recall: 0.31
# userid: 31085 - len(top_movies): 50 - training_data: 64 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 83567 - len(top_movies): 50 - training_data: 53 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 135075 - len(top_movies): 50 - training_data: 325 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 64214 - len(top_movies): 50 - training_data: 224 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 3296 - len(top_movies): 50 - training_data: 2 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 68049 - len(top_movies): 50 - training_data: 36 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 65154 - len(top_movies): 50 - training_data: 85 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 9300 - len(top_movies): 50 - training_data: 127 - test_data: 100 - window: 10 - hits: 26 recall: 0.26
# userid: 25880 - len(top_movies): 50 - training_data: 161 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 572 - len(top_movies): 50 - training_data: 568 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 87335 - len(top_movies): 50 - training_data: 13 - test_data: 100 - window: 10 - hits: 32 recall: 0.32
# userid: 89864 - len(top_movies): 50 - training_data: 133 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 28557 - len(top_movies): 50 - training_data: 7 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 63005 - len(top_movies): 50 - training_data: 39 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 103389 - len(top_movies): 50 - training_data: 13 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 105703 - len(top_movies): 50 - training_data: 49 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 40960 - len(top_movies): 50 - training_data: 215 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 101673 - len(top_movies): 50 - training_data: 26 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 110089 - len(top_movies): 50 - training_data: 157 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 21909 - len(top_movies): 50 - training_data: 142 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 4474 - len(top_movies): 50 - training_data: 3 - test_data: 100 - window: 10 - hits: 33 recall: 0.33
# userid: 36294 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 12968 - len(top_movies): 50 - training_data: 33 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 4442 - len(top_movies): 50 - training_data: 76 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 11132 - len(top_movies): 50 - training_data: 89 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 85914 - len(top_movies): 50 - training_data: 25 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 124100 - len(top_movies): 50 - training_data: 36 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 32300 - len(top_movies): 50 - training_data: 214 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 10199 - len(top_movies): 50 - training_data: 11 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 95190 - len(top_movies): 50 - training_data: 13 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 115937 - len(top_movies): 50 - training_data: 76 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 27366 - len(top_movies): 50 - training_data: 42 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 118111 - len(top_movies): 50 - training_data: 89 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 20178 - len(top_movies): 50 - training_data: 21 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 47680 - len(top_movies): 50 - training_data: 2 - test_data: 100 - window: 10 - hits: 2 recall: 0.02
# userid: 113996 - len(top_movies): 50 - training_data: 36 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 61346 - len(top_movies): 50 - training_data: 22 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 123259 - len(top_movies): 50 - training_data: 158 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 62454 - len(top_movies): 50 - training_data: 15 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 49598 - len(top_movies): 50 - training_data: 106 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 2137 - len(top_movies): 50 - training_data: 1 - test_data: 100 - window: 10 - hits: 33 recall: 0.33
# userid: 110247 - len(top_movies): 50 - training_data: 12 - test_data: 100 - window: 10 - hits: 26 recall: 0.26
# userid: 40468 - len(top_movies): 50 - training_data: 146 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 70907 - len(top_movies): 50 - training_data: 51 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 8737 - len(top_movies): 50 - training_data: 7 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 44597 - len(top_movies): 50 - training_data: 8 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 80829 - len(top_movies): 50 - training_data: 7 - test_data: 100 - window: 10 - hits: 46 recall: 0.46
# userid: 89836 - len(top_movies): 50 - training_data: 75 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# ...
# userid: 101014 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 54211 - len(top_movies): 50 - training_data: 9 - test_data: 100 - window: 10 - hits: 32 recall: 0.32
# userid: 62348 - len(top_movies): 50 - training_data: 36 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 12044 - len(top_movies): 50 - training_data: 202 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 32824 - len(top_movies): 50 - training_data: 7 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 44329 - len(top_movies): 50 - training_data: 88 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 83407 - len(top_movies): 50 - training_data: 20 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 121660 - len(top_movies): 50 - training_data: 32 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 134210 - len(top_movies): 50 - training_data: 342 - test_data: 100 - window: 10 - hits: 2 recall: 0.02
# userid: 5014 - len(top_movies): 50 - training_data: 28 - test_data: 100 - window: 10 - hits: 39 recall: 0.39
# userid: 18029 - len(top_movies): 50 - training_data: 285 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 104709 - len(top_movies): 50 - training_data: 77 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 138110 - len(top_movies): 50 - training_data: 70 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 40202 - len(top_movies): 50 - training_data: 4 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 83352 - len(top_movies): 50 - training_data: 22 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 98479 - len(top_movies): 50 - training_data: 203 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 68695 - len(top_movies): 50 - training_data: 137 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 91618 - len(top_movies): 50 - training_data: 102 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 83904 - len(top_movies): 50 - training_data: 167 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 131757 - len(top_movies): 50 - training_data: 122 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 71755 - len(top_movies): 50 - training_data: 45 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 28279 - len(top_movies): 50 - training_data: 127 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 45483 - len(top_movies): 50 - training_data: 173 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 4570 - len(top_movies): 50 - training_data: 54 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 125761 - len(top_movies): 50 - training_data: 45 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 98816 - len(top_movies): 50 - training_data: 48 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 82685 - len(top_movies): 50 - training_data: 14 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 35950 - len(top_movies): 50 - training_data: 167 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 40301 - len(top_movies): 50 - training_data: 13 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 94302 - len(top_movies): 50 - training_data: 81 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 84094 - len(top_movies): 50 - training_data: 50 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 71231 - len(top_movies): 50 - training_data: 138 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 110332 - len(top_movies): 50 - training_data: 97 - test_data: 100 - window: 10 - hits: 4 recall: 0.04
# userid: 125323 - len(top_movies): 50 - training_data: 52 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 51487 - len(top_movies): 50 - training_data: 32 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 78556 - len(top_movies): 50 - training_data: 47 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 121149 - len(top_movies): 50 - training_data: 26 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 31554 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 100054 - len(top_movies): 50 - training_data: 164 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 130646 - len(top_movies): 50 - training_data: 3 - test_data: 100 - window: 10 - hits: 26 recall: 0.26
# userid: 121606 - len(top_movies): 50 - training_data: 103 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 38294 - len(top_movies): 50 - training_data: 2 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 47858 - len(top_movies): 50 - training_data: 15 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 69977 - len(top_movies): 50 - training_data: 42 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 73168 - len(top_movies): 50 - training_data: 17 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 45065 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 53709 - len(top_movies): 50 - training_data: 30 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 93470 - len(top_movies): 50 - training_data: 116 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 30160 - len(top_movies): 50 - training_data: 101 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 110466 - len(top_movies): 50 - training_data: 38 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 16861 - len(top_movies): 50 - training_data: 81 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 30136 - len(top_movies): 50 - training_data: 166 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 70570 - len(top_movies): 50 - training_data: 203 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 103724 - len(top_movies): 50 - training_data: 12 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 125295 - len(top_movies): 50 - training_data: 24 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 23714 - len(top_movies): 50 - training_data: 148 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 81161 - len(top_movies): 50 - training_data: 59 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 36641 - len(top_movies): 50 - training_data: 47 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 45420 - len(top_movies): 50 - training_data: 111 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 6308 - len(top_movies): 50 - training_data: 1 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 70383 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 85495 - len(top_movies): 50 - training_data: 154 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 64168 - len(top_movies): 50 - training_data: 20 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 87954 - len(top_movies): 50 - training_data: 384 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 21488 - len(top_movies): 50 - training_data: 18 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 67477 - len(top_movies): 50 - training_data: 29 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 102543 - len(top_movies): 50 - training_data: 29 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 91015 - len(top_movies): 50 - training_data: 88 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 1854 - len(top_movies): 50 - training_data: 339 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 50430 - len(top_movies): 50 - training_data: 37 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 11511 - len(top_movies): 50 - training_data: 257 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 124909 - len(top_movies): 50 - training_data: 95 - test_data: 100 - window: 10 - hits: 1 recall: 0.01
# userid: 42563 - len(top_movies): 50 - training_data: 205 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 101637 - len(top_movies): 50 - training_data: 129 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 60619 - len(top_movies): 50 - training_data: 28 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 32233 - len(top_movies): 50 - training_data: 57 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 13791 - len(top_movies): 50 - training_data: 26 - test_data: 100 - window: 10 - hits: 34 recall: 0.34
# userid: 10685 - len(top_movies): 50 - training_data: 27 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 118344 - len(top_movies): 50 - training_data: 19 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 42791 - len(top_movies): 50 - training_data: 69 - test_data: 100 - window: 10 - hits: 13 recall: 0.13
# userid: 93749 - len(top_movies): 50 - training_data: 77 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 101440 - len(top_movies): 50 - training_data: 31 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 20819 - len(top_movies): 50 - training_data: 25 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 72343 - len(top_movies): 50 - training_data: 207 - test_data: 100 - window: 10 - hits: 6 recall: 0.06
# userid: 135062 - len(top_movies): 50 - training_data: 76 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 56129 - len(top_movies): 50 - training_data: 52 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 5792 - len(top_movies): 50 - training_data: 40 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 135234 - len(top_movies): 50 - training_data: 81 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 75694 - len(top_movies): 50 - training_data: 11 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 48565 - len(top_movies): 50 - training_data: 160 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 73366 - len(top_movies): 50 - training_data: 20 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 67971 - len(top_movies): 50 - training_data: 28 - test_data: 100 - window: 10 - hits: 19 recall: 0.19
# userid: 43974 - len(top_movies): 50 - training_data: 105 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 47388 - len(top_movies): 50 - training_data: 85 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 1528 - len(top_movies): 50 - training_data: 69 - test_data: 100 - window: 10 - hits: 29 recall: 0.29
# userid: 116677 - len(top_movies): 50 - training_data: 171 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 3264 - len(top_movies): 50 - training_data: 62 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 116 - len(top_movies): 50 - training_data: 98 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 12904 - len(top_movies): 50 - training_data: 6 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 116523 - len(top_movies): 50 - training_data: 129 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 54881 - len(top_movies): 50 - training_data: 120 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 38081 - len(top_movies): 50 - training_data: 63 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 84189 - len(top_movies): 50 - training_data: 3 - test_data: 100 - window: 10 - hits: 11 recall: 0.11
# userid: 89245 - len(top_movies): 50 - training_data: 46 - test_data: 100 - window: 10 - hits: 30 recall: 0.3
# userid: 49308 - len(top_movies): 50 - training_data: 50 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 42199 - len(top_movies): 50 - training_data: 94 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 20530 - len(top_movies): 50 - training_data: 242 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 1458 - len(top_movies): 50 - training_data: 31 - test_data: 100 - window: 10 - hits: 25 recall: 0.25
# userid: 98871 - len(top_movies): 50 - training_data: 304 - test_data: 100 - window: 10 - hits: 1 recall: 0.01
# userid: 102004 - len(top_movies): 50 - training_data: 68 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 93568 - len(top_movies): 50 - training_data: 170 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 123402 - len(top_movies): 50 - training_data: 275 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 34683 - len(top_movies): 50 - training_data: 215 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 108924 - len(top_movies): 50 - training_data: 16 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 6371 - len(top_movies): 50 - training_data: 120 - test_data: 100 - window: 10 - hits: 16 recall: 0.16
# userid: 28916 - len(top_movies): 50 - training_data: 276 - test_data: 100 - window: 10 - hits: 3 recall: 0.03
# userid: 67237 - len(top_movies): 50 - training_data: 35 - test_data: 100 - window: 10 - hits: 31 recall: 0.31
# userid: 9753 - len(top_movies): 50 - training_data: 159 - test_data: 100 - window: 10 - hits: 7 recall: 0.07
# userid: 121793 - len(top_movies): 50 - training_data: 42 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 67303 - len(top_movies): 50 - training_data: 351 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 20520 - len(top_movies): 50 - training_data: 22 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 136844 - len(top_movies): 50 - training_data: 145 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 14319 - len(top_movies): 50 - training_data: 45 - test_data: 100 - window: 10 - hits: 14 recall: 0.14
# userid: 67563 - len(top_movies): 50 - training_data: 317 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 77496 - len(top_movies): 50 - training_data: 114 - test_data: 100 - window: 10 - hits: 18 recall: 0.18
# userid: 81867 - len(top_movies): 50 - training_data: 10 - test_data: 100 - window: 10 - hits: 24 recall: 0.24
# userid: 45656 - len(top_movies): 50 - training_data: 54 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 108008 - len(top_movies): 50 - training_data: 10 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 132674 - len(top_movies): 50 - training_data: 1 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 14828 - len(top_movies): 50 - training_data: 33 - test_data: 100 - window: 10 - hits: 31 recall: 0.31
# userid: 92693 - len(top_movies): 50 - training_data: 184 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 51172 - len(top_movies): 50 - training_data: 55 - test_data: 100 - window: 10 - hits: 21 recall: 0.21
# userid: 37503 - len(top_movies): 50 - training_data: 34 - test_data: 100 - window: 10 - hits: 17 recall: 0.17
# userid: 79921 - len(top_movies): 50 - training_data: 3 - test_data: 100 - window: 10 - hits: 8 recall: 0.08
# userid: 52095 - len(top_movies): 50 - training_data: 69 - test_data: 100 - window: 10 - hits: 22 recall: 0.22
# userid: 46458 - len(top_movies): 50 - training_data: 112 - test_data: 100 - window: 10 - hits: 23 recall: 0.23
# userid: 116204 - len(top_movies): 50 - training_data: 70 - test_data: 100 - window: 10 - hits: 5 recall: 0.05
# userid: 100071 - len(top_movies): 50 - training_data: 12 - test_data: 100 - window: 10 - hits: 9 recall: 0.09
# userid: 11563 - len(top_movies): 50 - training_data: 44 - test_data: 100 - window: 10 - hits: 20 recall: 0.2
# userid: 74870 - len(top_movies): 50 - training_data: 44 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# userid: 84925 - len(top_movies): 50 - training_data: 79 - test_data: 100 - window: 10 - hits: 28 recall: 0.28
# userid: 51631 - len(top_movies): 50 - training_data: 104 - test_data: 100 - window: 10 - hits: 15 recall: 0.15
# userid: 36313 - len(top_movies): 50 - training_data: 88 - test_data: 100 - window: 10 - hits: 10 recall: 0.1
# userid: 113109 - len(top_movies): 50 - training_data: 167 - test_data: 100 - window: 10 - hits: 12 recall: 0.12
# total users: 10000 - users not consid. 6485 - total_recall: 526.3499999999991
#
# === Final Results ===
# Recall@50: 0.1497

# %%
K = 50
total_recall = 0
users_not_considered = 0
recalls = []
total_precision = 0
user_recommendations = {}
train_ratings_sorted = train_ratings.sort_values(['userId', 'timestamp'])

for user_id in selected_user_ids:
    user_data = train_ratings_sorted[train_ratings_sorted['userId'] == user_id]
    user_training_samples = len(user_data)
    
    # Only consider last 5 samples
    recent_movies = user_data['movieId'].tail(1).tolist()
    
    candidate_scores = {}
    
    # Process only the last 5 movies
    for movie_id in recent_movies:
        probabilities = model.transition_matrix[model.movie_to_idx[movie_id]]
        top_indices = np.argsort(probabilities)[-(K):][::-1]
        
        for i in top_indices:
            candidate_movie_id = model.idx_to_movie[i]
            candidate_prob = probabilities[i]
            
            # Skip if user has already rated this movie
            if candidate_movie_id in user_data['movieId'].values:
                continue
                
            # Keep the highest probability for each movie
            if candidate_movie_id not in candidate_scores:
                candidate_scores[candidate_movie_id] = candidate_prob
            elif candidate_prob > candidate_scores[candidate_movie_id]:
                candidate_scores[candidate_movie_id] = candidate_prob
    
    # Get top K movies from candidate scores
    top_movies = sorted(candidate_scores.items(), key=lambda x: x[1], reverse=True)[:K]
    
    if len(top_movies) < K:
        users_not_considered += 1
        # print(f"userid: {user_id} - Insufficient recommendations: {len(top_movies)}/{K} - Skipping")
        continue
        
    candidate_movies = [movie_id for movie_id, score in top_movies]
    recommended_movies = set(candidate_movies)
    user_test_ratings = test_ratings[test_ratings['userId'] == user_id]
    relevant_movies = set(user_test_ratings['movieId'].tolist())
    
    # Validation
    hits = relevant_movies.intersection(recommended_movies)
    
    user_recall = 0
    if len(relevant_movies) > 0:
        user_recall = len(hits) / len(relevant_movies)
        total_recall += user_recall    
    recalls.append(user_recall)
    
    if len(recommended_movies) > 0:
        user_precision = len(hits) / len(recommended_movies)
        total_precision += user_precision

    print(f"userid: {user_id} - recent_movies: {len(recent_movies)} - recommendations: {len(top_movies)} - test_data: {len(relevant_movies)} - hits: {len(hits)} - recall: {user_recall:.4f}")

print(f"total users: {len(selected_user_ids)} - users not consid. {users_not_considered} - total_recall: {total_recall}")

if (len(selected_user_ids) - users_not_considered) > 0:
    avg_recall = total_recall / (len(selected_user_ids) - users_not_considered)
    avg_precision = total_precision / (len(selected_user_ids) - users_not_considered)
else:
    avg_recall = 0
    avg_precision = 0

print("\n=== Final Results ===")
print(f"Recall@{K}: {avg_recall:.4f}")
print(f"Precision@{K}: {avg_precision:.4f}")
# Out:
# userid: 58606 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 34 - recall: 0.3400
# userid: 137151 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 3 - recall: 0.0300
# userid: 116479 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 47743 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 58327 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 123958 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 122728 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 17 - recall: 0.1700
# userid: 80029 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 111335 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 55021 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 30 - recall: 0.3000
# userid: 108545 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 32 - recall: 0.3200
# userid: 106171 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 7 - recall: 0.0700
# userid: 32656 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 29 - recall: 0.2900
# userid: 38074 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 25596 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 27213 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 38791 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 25022 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 121748 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 55157 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 919 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 15432 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 17399 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 31 - recall: 0.3100
# userid: 8645 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 28 - recall: 0.2800
# userid: 3296 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 28557 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 10199 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 2137 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 33 - recall: 0.3300
# userid: 110247 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 93571 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 2314 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 29615 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 30 - recall: 0.3000
# userid: 31311 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 27022 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 5 - recall: 0.0500
# userid: 65955 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 17831 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 25 - recall: 0.2500
# userid: 127489 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 87685 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 110407 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 23280 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 89148 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 134896 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 33381 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 97178 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 41443 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 121280 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 108532 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 28333 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 17 - recall: 0.1700
# userid: 9949 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 94584 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 73100 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 67057 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 119604 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 37 - recall: 0.3700
# userid: 71788 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 7 - recall: 0.0700
# userid: 117226 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 83849 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 100008 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# userid: 92791 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 2 - recall: 0.0200
# userid: 56299 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 132486 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 47822 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 34 - recall: 0.3400
# userid: 44217 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 3 - recall: 0.0300
# userid: 16134 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 8 - recall: 0.0800
# userid: 77743 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 119643 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 41896 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 30 - recall: 0.3000
# userid: 66230 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 89605 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 123698 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 23326 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 124741 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 6 - recall: 0.0600
# userid: 64180 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 34387 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 48039 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 84468 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 3 - recall: 0.0300
# userid: 85936 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 28 - recall: 0.2800
# userid: 33387 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# userid: 16743 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 28 - recall: 0.2800
# userid: 88295 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 32 - recall: 0.3200
# userid: 50877 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 114005 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 30079 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 107946 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 37 - recall: 0.3700
# userid: 128807 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 121714 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 79977 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 30 - recall: 0.3000
# userid: 23128 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 12578 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 7 - recall: 0.0700
# userid: 135839 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 4 - recall: 0.0400
# userid: 47818 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 6 - recall: 0.0600
# userid: 42990 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 110643 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 29 - recall: 0.2900
# userid: 10878 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 1437 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 49185 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 54726 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 48641 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 29258 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 6 - recall: 0.0600
# userid: 24217 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 99127 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 28 - recall: 0.2800
# userid: 5927 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 7463 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 5186 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 93187 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 134264 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 43453 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 30 - recall: 0.3000
# userid: 78081 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 46766 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 127117 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 89441 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 42677 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 49306 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 35906 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 84754 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 82784 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 91169 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 134982 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 10606 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 136494 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 34 - recall: 0.3400
# userid: 90712 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 136292 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 30 - recall: 0.3000
# userid: 123135 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 7992 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 129689 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 24095 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# userid: 52358 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 78860 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 114221 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 50726 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 133107 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 66348 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 60710 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 20139 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 17 - recall: 0.1700
# userid: 99727 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 31 - recall: 0.3100
# userid: 100630 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 23839 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 133946 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 122681 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 31 - recall: 0.3100
# userid: 71299 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 84610 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 120330 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 31 - recall: 0.3100
# userid: 83963 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 38281 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 8 - recall: 0.0800
# userid: 130266 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 113583 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 138029 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 88324 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 25 - recall: 0.2500
# userid: 115923 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 1690 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 16325 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 57622 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 99356 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 8 - recall: 0.0800
# userid: 39472 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 33 - recall: 0.3300
# userid: 84315 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 120120 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 88574 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 64830 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 76683 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 102582 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 127315 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 122917 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 17105 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# userid: 1719 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 92639 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 123095 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 32196 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 100276 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 59960 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 100383 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 39662 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 10546 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 19470 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 79406 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 55327 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 92672 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 90602 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 63820 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 32 - recall: 0.3200
# userid: 72357 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 30 - recall: 0.3000
# userid: 51999 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 25 - recall: 0.2500
# userid: 105914 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 97012 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 75371 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# userid: 131756 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 14 - recall: 0.1400
# userid: 137068 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 5 - recall: 0.0500
# userid: 101661 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 25 - recall: 0.2500
# userid: 37443 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 31 - recall: 0.3100
# userid: 83183 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 34757 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 87569 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 17 - recall: 0.1700
# userid: 135539 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 28781 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 130805 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 29 - recall: 0.2900
# userid: 42256 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 19013 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 62734 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 18475 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 17 - recall: 0.1700
# userid: 8443 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 71307 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 70849 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 25 - recall: 0.2500
# userid: 8047 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 97566 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 51059 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 118197 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 121010 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 128289 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 74939 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 39238 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 14793 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 40 - recall: 0.4000
# userid: 96904 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 1356 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 30 - recall: 0.3000
# userid: 65067 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# userid: 56096 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 83691 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 31 - recall: 0.3100
# userid: 105025 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 60223 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 111050 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 32 - recall: 0.3200
# userid: 52005 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 101072 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 25 - recall: 0.2500
# userid: 20516 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 116743 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 60755 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 72669 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 24 - recall: 0.2400
# userid: 94088 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 92116 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# userid: 76272 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 113982 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 65688 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 88720 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 101483 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 16 - recall: 0.1600
# userid: 13293 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 29 - recall: 0.2900
# userid: 106481 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# userid: 95912 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 27866 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 29 - recall: 0.2900
# userid: 32115 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 22561 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 59439 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 30742 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 87835 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 33 - recall: 0.3300
# userid: 58203 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 28 - recall: 0.2800
# userid: 84270 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 31 - recall: 0.3100
# userid: 19251 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 65258 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 72010 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 10365 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 21 - recall: 0.2100
# userid: 136156 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 43505 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 47573 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 17 - recall: 0.1700
# userid: 94003 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 27 - recall: 0.2700
# userid: 4996 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 9101 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 34 - recall: 0.3400
# userid: 86015 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 117952 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 15 - recall: 0.1500
# userid: 112181 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 34 - recall: 0.3400
# userid: 11017 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 20 - recall: 0.2000
# userid: 117196 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 56872 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 34 - recall: 0.3400
# userid: 22230 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 32538 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 115142 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 23 - recall: 0.2300
# userid: 100274 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 18 - recall: 0.1800
# userid: 19992 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 13 - recall: 0.1300
# userid: 25236 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 26 - recall: 0.2600
# userid: 91738 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 19 - recall: 0.1900
# userid: 39401 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 32 - recall: 0.3200
# userid: 18786 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 17 - recall: 0.1700
# userid: 132470 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 11 - recall: 0.1100
# userid: 10234 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 101014 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 10 - recall: 0.1000
# userid: 54211 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 32 - recall: 0.3200
# userid: 32824 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 4 - recall: 0.0400
# userid: 130646 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 38294 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 6 - recall: 0.0600
# userid: 36641 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 12 - recall: 0.1200
# userid: 6308 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 12904 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 132674 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 22 - recall: 0.2200
# userid: 79921 - recent_movies: 1 - recommendations: 50 - test_data: 100 - hits: 9 - recall: 0.0900
# total users: 10000 - users not consid. 9723 - total_recall: 53.14999999999997
#
# === Final Results ===
# Recall@50: 0.1919
# Precision@50: 0.3838
